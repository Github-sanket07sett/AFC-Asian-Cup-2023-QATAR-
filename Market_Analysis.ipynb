# %% [markdown]
# <a href="https://colab.research.google.com/github/Github-sanket07sett/AFC-Asian-Cup-2023-QATAR-/blob/main/Market_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/content/drive/MyDrive/Dataset/onyx data.csv',encoding='latin-1')
df.head(3)
# Out:
#   Campaign Month Day of the Week           Date        City   Channel  \
# 0  Spring    Mar             Wed  01 March 2023  Birmingham  Facebook
# 1  Spring    Mar             Thu  02 March 2023  Birmingham  Facebook
# 2  Spring    Mar             Fri  03 March 2023  Birmingham  Facebook
#
#     Device          Ad  Impressions   CTR  Clicks  Daily Average CPC  \
# 0  Desktop  Collection       1110.8  1.9%      21               1.39
# 1  Desktop  Collection       1296.6  1.1%      14               0.72
# 2  Desktop  Collection       1264.4  1.3%      17               0.38
#
#    Spend, GBP  Conversions  Total conversion value, GBP  Likes (Reactions)  \
# 0       28.60            1                        51.84                 45
# 1       10.33            2                        40.32                 14
# 2        6.33            4                        53.76                 24
#
#    Shares  Comments
# 0       4         3
# 1      17        11
# 2       1         8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9900 entries, 0 to 9899
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Campaign                     9900 non-null   object
#  1   Month                        9900 non-null   object
#  2   Day of the Week              9900 non-null   object
#  3   Date                         9900 non-null   object
#  4   City                         9900 non-null   object
#  5   Channel                      9900 non-null   object
#  6   Device                       9900 non-null   object
#  7   Ad                           9900 non-null   object
#  8   Impressions                  9900 non-null   float64
#  9   CTR                          9900 non-null   object
#  10  Clicks                       9900 non-null   int64
#  11  Daily Average CPC            9900 non-null   float64
#  12  Spend, GBP                   9900 non-null   float64
#  13  Conversions                  9900 non-null   int64
#  14  Total conversion value, GBP  9900 non-null   float64
#  15  Likes (Reactions)            9900 non-null   int64
#  16  Shares                       9900 non-null   int64
#  17  Comments                     9900 non-null   int64
# dtypes: float64(4), int64(5), object(9)
# memory usage: 1.4+ MB

# %%
df.shape
# Out:
# (9900, 18)

# %%
df.tail(3)
# Out:
#      Campaign Month Day of the Week              Date        City    Channel  \
# 9897    Fall    Nov             Tue  28 November 2023  Manchester  Pinterest
# 9898    Fall    Nov             Wed  29 November 2023  Manchester  Pinterest
# 9899    Fall    Nov             Thu  30 November 2023  Manchester  Pinterest
#
#       Device        Ad  Impressions   CTR  Clicks  Daily Average CPC  \
# 9897  Mobile  Discount       2423.0  1.3%      31               0.31
# 9898  Mobile  Discount       1778.0  1.1%      19               0.88
# 9899  Mobile  Discount       1607.0  0.6%       9               0.79
#
#       Spend, GBP  Conversions  Total conversion value, GBP  Likes (Reactions)  \
# 9897        9.46            3                        232.0                 64
# 9898       16.74            4                        305.0                 88
# 9899        7.24            7                        298.0                 70
#
#       Shares  Comments
# 9897      12         5
# 9898      15         1
# 9899      18         5

# %%
df.iloc[0]
# Out:
# Campaign                               Spring
# Month                                      Mar
# Day of the Week                            Wed
# Date                             01 March 2023
# City                                Birmingham
# Channel                               Facebook
# Device                                 Desktop
# Ad                                  Collection
# Impressions                             1110.8
# CTR                                       1.9%
# Clicks                                      21
#  Daily Average CPC                      £1.39
#  Spend, GBP                            £28.60
# Conversions                                  1
#  Total conversion value, GBP           £51.84
# Likes (Reactions)                           45
# Shares                                       4
# Comments                                     3
# Name: 0, dtype: object

# %%
# Calculate the total conversion value
total_conversion_value = df['Total conversion value, GBP'].sum()

print("Total Conversion Value, GBP: ", total_conversion_value)

#average total sales
average_total_sales = df['Total conversion value, GBP'].mean()

print("Average Total Sales, GBP: ", average_total_sales)
# Out:
# Total Conversion Value, GBP:  1731700.26
# Average Total Sales, GBP:  174.9192181818182

# %%
total_sales_monthly=df["Total conversion value, GBP"].groupby(df["Month"]).sum()
print(total_sales_monthly)
#bar chart
months = total_sales_monthly.index
sales = total_sales_monthly.values
colors = ['blue', 'green', 'red', 'purple', 'orange', 'brown', 'pink', 'gray', 'olive', 'cyan', 'magenta', 'yellow']
plt.bar(months,sales,color=colors)
plt.xticks(rotation=45  )
plt.xlabel('Month')
plt.ylabel('Total conversion value, GBP')
plt.title('Total Sales per Month')
plt.show()
# Out:
# Month
# Apr    165200.43
# Aug    157331.98
# Jul    166387.28
# Jun    160689.95
# Mar    162820.54
# May    170264.09
# Nov    258588.37
# Oct    254070.02
# Sep    236347.60
# Name: Total conversion value, GBP, dtype: float64

# %%
total_sales_city=df["Total conversion value, GBP"].groupby(df["City"]).sum()
print(total_sales_city)

plt.pie(total_sales_city,labels=total_sales_city.index,autopct='%1.1f%%')
plt.title('total sales per city')
plt.show()
# Out:
# City
# Birmingham    550018.96
# London        532011.43
# Manchester    649669.87
# Name: Total conversion value, GBP, dtype: float64

# %%
Total_sales_per_day=df["Total conversion value, GBP"].groupby(df["Day of the Week"]).sum()
print(Total_sales_per_day)
plt.pie(Total_sales_per_day,labels=Total_sales_per_day.index,autopct='%1.1f%%')
plt.title('Total Sales per Day')
plt.show()
# Out:
# Day of the Week
# Fri    246877.21
# Mon    246321.51
# Sat    244394.34
# Sun    244775.75
# Thu    248075.50
# Tue    251562.09
# Wed    249693.86
# Name: Total conversion value, GBP, dtype: float64

# %%
Total_sales_channel=df["Total conversion value, GBP"].groupby(df["Channel"]).sum()
print(Total_sales_channel)
plt.pie(Total_sales_channel,labels=Total_sales_channel.index,autopct='%1.1f%%')
plt.title('Total Sales per Channel')
plt.show()
# Out:
# Channel
# Facebook     412225.78
# Instagram    684760.68
# Pinterest    634713.80
# Name: Total conversion value, GBP, dtype: float64

# %%
#calculate total Spend
total_spend = df['Spend, GBP'].sum()

print("Total Spend, GBP: ", total_spend)
#average spend
average_spend = df['Spend, GBP'].mean()

print("Average Spend, GBP: ", average_spend)
# Out:
# Total Spend, GBP:  163249.83000000002
# Average Spend, GBP:  16.48988181818182

# %%
total_spend_city = df["Spend, GBP"].groupby(df["City"]).sum()
print(total_spend_city)

plt.pie(total_spend_city,labels=total_spend_city.index,autopct='%1.1f%%')
plt.title('total spend per city')
plt.show()
# Out:
# City
# Birmingham    39484.12
# London        66704.46
# Manchester    57061.25
# Name: Spend, GBP, dtype: float64

# %%
#total spend per month

Total_spend_monthly=df["Spend, GBP"].groupby(df["Month"]).sum()
print(Total_spend_monthly)
months = Total_spend_monthly.index
spend = Total_spend_monthly.values
colors = ['blue', 'green', 'red', 'purple', 'orange', 'brown', 'pink', 'gray', 'olive', 'cyan', 'magenta', 'yellow']
plt.bar(months,spend,color=colors)
plt.xticks(rotation=45  )
plt.xlabel('Month')
plt.ylabel('Spend, GBP')
plt.title('Total Spend per Month')
plt.show()
# Out:
# Month
# Apr    16649.95
# Aug    11438.26
# Jul    11528.16
# Jun    11415.03
# Mar    15317.42
# May    17587.01
# Nov    25556.42
# Oct    26694.37
# Sep    27063.21
# Name: Spend, GBP, dtype: float64

# %%
Roi=(((df['Total conversion value, GBP'].sum()-df['Spend, GBP'].sum())/df['Spend, GBP'].sum())*100)

print("Return on Investment:",Roi)
# Out:
# Return on Investment: 960.7669606761611
# Return on Investment by City: City
# Birmingham    1293.013090
# London         697.565005
# Manchester    1038.548262
# dtype: float64

# %%
Total_clicks=df['Clicks'].sum()
print("total Clicks:",Total_clicks)
#average clicks
average_clicks=df['Clicks'].mean()
print('average clicks:',average_clicks)
# Out:
# total Clicks: 181598
# average clicks: 18.343232323232325

# %%
#total Shares
total_shares=df['Shares'].sum()
print('Total Shares:',total_shares)

#average shares
average_shares=df['Shares'].mean()
print('average shares:',average_shares)
#total comments
total_comments=df['Comments'].sum()
print("total comments:",total_comments)
#average comments
average_comments=df['Comments'].mean()
print('average comments:',average_comments)
#
# Out:
# Total Shares: 120515
# Month
# Apr    10738
# Aug    12118
# Jul    14041
# Jun    14409
# Mar    10525
# May    12067
# Nov    15572
# Oct    16112
# Sep    14933
# Name: Shares, dtype: int64
# average shares: 12.173232323232323
# total comments: 72739
# average comments: 7.347373737373737

# %%
#calculate total clicks
Total_clicks=df['Clicks'].sum()
print("total Clicks:",Total_clicks)
#average clicks
average_clicks=df['Clicks'].mean()
print('average clicks:',average_clicks)
plt.bar(df['Month'],df['Clicks'])
plt.xlabel('Month')
plt.ylabel('Clicks')
plt.title('Total Clicks per Month')
plt.show()
# Out:
# total Clicks: 181598
# average clicks: 18.343232323232325

# %%
total_spend_channel=df['Spend, GBP'].groupby(df["Channel"]).sum()
print(total_spend_channel)
plt.pie(total_spend_channel,labels=total_spend_channel.index,autopct='%1.1f%%')
plt.title('Total Spend per Channel')
plt.show()
# Out:
# Channel
# Facebook     71612.59
# Instagram    63393.83
# Pinterest    28243.41
# Name: Spend, GBP, dtype: float64

# %%
Total_sales_channel=df['Total conversion value, GBP'].groupby(df["Channel"]).sum()
print(Total_sales_channel)
plt.pie(Total_sales_channel,labels=Total_sales_channel.index,autopct='%1.1f%%')
plt.title('Total Sales per Channel')

plt.show()
# Out:
# Channel
# Facebook     412225.78
# Instagram    684760.68
# Pinterest    634713.80
# Name: Total conversion value, GBP, dtype: float64

# %%
total_sales_per_device=df['Total conversion value, GBP'].groupby(df["Device"]).sum()
print(total_sales_per_device)
plt.pie(total_sales_per_device,labels=total_sales_per_device.index,autopct='%1.1f%%')
plt.title('Total Sales from Device type')
plt.show()
# Out:
# Device
# Desktop    949684.24
# Mobile     782016.02
# Name: Total conversion value, GBP, dtype: float64

# %%
#Total sales per ad
total_sales_per_ads = df['Total conversion value, GBP'].groupby(df["Ad"]).sum()
print(total_sales_per_ads)
plt.pie(total_sales_per_ads,labels=total_sales_per_ads.index,autopct='%1.1f%%',startangle=90)
plt.title('Total Sales from Ad types')
plt.legend(prop={'size': 8})
plt.show()
# Out:
# Ad
# Collection     657638.83
# Discount      1074061.43
# Name: Total conversion value, GBP, dtype: float64

# %%
#Calculate Roas
ROAS=df['Total conversion value, GBP'].sum()/df['Spend, GBP'].sum()
print("Return of Ad Spend:",ROAS)
#ROAS Per Month
ROAS_per_month=df['Total conversion value, GBP'].groupby(df["Month"]).sum()/df['Spend, GBP'].groupby(df["Month"]).sum()
print(ROAS_per_month)
months = ROAS_per_month.index
roas = ROAS_per_month.values
plt.bar(months,roas)
plt.xlabel('Month')
plt.ylabel('ROAS')
plt.title('ROAS per Month')
plt.show()
# Out:
# Return of Ad Spend: 10.607669606761611
# Month
# Apr     9.921978
# Aug    13.754888
# Jul    14.433117
# Jun    14.077050
# Mar    10.629763
# May     9.681241
# Nov    10.118333
# Oct     9.517738
# Sep     8.733169
# dtype: float64

# %%
#Roas per City
ROAS_per_city=df['Total conversion value, GBP'].groupby(df["City"]).sum()/df['Spend, GBP'].groupby(df["City"]).sum()
print(ROAS_per_city)
plt.pie(ROAS_per_city,labels=ROAS_per_city.index,autopct='%1.1f%%')
plt.title('ROAS per City')
plt.show()
# Out:
# City
# Birmingham    13.930131
# London         7.975650
# Manchester    11.385483
# dtype: float64

# %%
Roas_by_device=df['Total conversion value, GBP'].groupby(df["Device"]).sum()/df['Spend, GBP'].groupby(df["Device"]).sum()
print(Roas_by_device)
plt.pie(Roas_by_device,labels=Roas_by_device.index,autopct='%1.1f%%')
plt.title('ROAS by Device')
plt.show()
# Out:
# Device
# Desktop    11.014807
# Mobile     10.151970
# dtype: float64

# %%
Total_sales_Campaign=df['Total conversion value, GBP'].groupby(df["Campaign"]).sum()
print(Total_sales_Campaign)
plt.bar(Total_sales_Campaign.index,Total_sales_Campaign.values)
plt.title('Total Sales per Campaign')
plt.show()
#
# Out:
# Campaign
# Fall        266385.50
# Spring     1308842.16
# Summer      156472.60
# Name: Total conversion value, GBP, dtype: float64

# %%
plt.scatter(df['Clicks'],df['Conversions'])
plt.xlabel('Clicks')
plt.ylabel(' conversion value, GBP')
plt.title('Clicks vs conversion ')
plt.show()

# %%
conversion_rate=(df['Conversions'].sum()/df['Clicks'].sum())*100
print("conversion rate:",conversion_rate)

conversion_city=df['Conversions'].groupby(df["City"]).sum()/df['Clicks'].groupby(df["City"]).sum()*100
print("Conversion from  city",conversion_city)

conversion_device=df['Conversions'].groupby(df["Device"]).sum()/df['Clicks'].groupby(df["Device"]).sum()*100
print("conversion from device",conversion_device)


conversion_month=df['Conversions'].groupby(df["Month"]).sum()/df['Clicks'].groupby(df["Month"]).sum()*100
print("conversion from month",conversion_month)
# Out:
# conversion rate: 22.165442350686682
# Conversion from  city City
# Birmingham    28.788663
# London        17.610469
# Manchester    22.863414
# dtype: float64
# conversion from device Device
# Desktop    23.989103
# Mobile     20.419119
# dtype: float64
# conversion from month Month
# Apr    21.825607
# Aug    31.708063
# Jul    32.568529
# Jun    34.355289
# Mar    23.232427
# May    20.564454
# Nov    19.251047
# Oct    17.485079
# Sep    15.744452
# dtype: float64

# %%
profit=df['Total conversion value, GBP'].sum()-df['Spend, GBP'].sum()
print("profit:",profit)
profit_per_month=df['Total conversion value, GBP'].groupby(df["Month"]).sum()-df['Spend, GBP'].groupby(df["Month"]).sum()
print("profit per month:",profit_per_month)
plt.bar(profit_per_month.index,profit_per_month.values)
plt.xlabel('Month')
plt.ylabel('Profit')
plt.title('Profit per Month')
plt.show()
# Out:
# profit: 1568450.43
# profit per month: Month
# Apr    148550.48
# Aug    145893.72
# Jul    154859.12
# Jun    149274.92
# Mar    147503.12
# May    152677.08
# Nov    233031.95
# Oct    227375.65
# Sep    209284.39
# dtype: float64

# %%
profit_city=df['Total conversion value, GBP'].groupby(df["City"]).sum()-df['Spend, GBP'].groupby(df["City"]).sum()
print("profit from city:",profit_city)
plt.bar(profit_city.index,profit_city.values)
plt.xlabel('City')
plt.ylabel('Profit')
plt.title('Profit from City')
plt.show()
#
# Out:
# profit from city: City
# Birmingham    510534.84
# London        465306.97
# Manchester    592608.62
# dtype: float64

# %%
profit_channel=df['Total conversion value, GBP'].groupby(df["Channel"]).sum()-df['Spend, GBP'].groupby(df["Channel"]).sum()
print("profit from channel:",profit_channel)
plt.bar(profit_channel.index,profit_channel.values)
plt.xlabel('Channel')
plt.ylabel('Profit')
plt.title('Profit from Channel')
plt.show()
#
# Out:
# profit from channel: Channel
# Facebook     340613.19
# Instagram    621366.85
# Pinterest    606470.39
# dtype: float64

# %%
profit_month=df['Total conversion value, GBP'].groupby(df["Month"]).sum()-df['Spend, GBP'].groupby(df["Month"]).sum()
print("profit from campaign:",profit_month)
plt.bar(profit_month.index,profit_month.values)
plt.xlabel('Month')
plt.ylabel('Profit')
plt.title('Profit from Month')
plt.show()
#
# Out:
# profit from campaign: Month
# Apr    148550.48
# Aug    145893.72
# Jul    154859.12
# Jun    149274.92
# Mar    147503.12
# May    152677.08
# Nov    233031.95
# Oct    227375.65
# Sep    209284.39
# dtype: float64

# %%
profit_device=df['Total conversion value, GBP'].groupby(df["Device"]).sum()-df['Spend, GBP'].groupby(df["Device"]).sum()
print("profit from device:",profit_device)
plt.pie(profit_device,labels=profit_device.index,autopct='%1.1f%%')
plt.title('Profit from Device')
plt.show()
#
# Out:
# profit from device: Device
# Desktop    863465.37
# Mobile     704985.06
# dtype: float64

# %%
#CPC by Channel
cpc_channel=df['Daily Average CPC'].groupby(df["Channel"]).sum()

print("cpc from channel:",cpc_channel)
colors = ['blue', 'green', 'red', 'purple', 'orange']
plt.barh(cpc_channel.index,cpc_channel.values,color=colors)

plt.xlabel('CPC')
plt.ylabel('Channel')
plt.title('CPC from Channel')

plt.show()
#
# Out:
# cpc from channel: Channel
# Facebook     3444.39
# Instagram    3295.76
# Pinterest    2210.48
# Name: Daily Average CPC, dtype: float64

# %%
# Create a pivot table
pivot_table = df.pivot_table(index='Channel', columns='Device', values='Daily Average CPC', aggfunc='sum')
print(pivot_table)
# Plot the stacked bar chart
pivot_table.plot(kind='bar', stacked=False)
plt.xlabel('Channel')
plt.ylabel('CPC')
plt.title('CPC from Channel and Device')
plt.show()
# Out:
# Device     Desktop   Mobile
# Channel
# Facebook   1861.59  1582.80
# Instagram  1780.32  1515.44
# Pinterest  1191.89  1018.59

# %%
cpc_ad=df['Daily Average CPC'].groupby(df["Ad"]).sum()
print("cpc from ad:",cpc_ad)
plt.pie(cpc_ad,labels=cpc_ad.index,autopct='%1.1f%%',startangle=90)
plt.title('CPC from Ad')
plt.legend(prop={'size': 8})

plt.show()
#
# Out:
# cpc from ad: Ad
# Collection    3329.03
# Discount      5621.60
# Name: Daily Average CPC, dtype: float64

# %%
cpc_device=df['Daily Average CPC'].groupby(df["Device"]).sum()
print("cpc from device:",cpc_device)
plt.pie(cpc_device,labels=cpc_device.index,autopct='%1.1f%%',startangle=90)
plt.title('CPC from Device')
plt.legend(prop={'size': 8})

plt.show()
#
# Out:
# cpc from device: Device
# Desktop    4833.80
# Mobile     4116.83
# Name: Daily Average CPC, dtype: float64

# %%
total_impressions_month=df['Impressions'].groupby(df["Month"]).sum()
print("total impressions:",total_impressions_month)
plt.bar(total_impressions_month.index,total_impressions_month.values)
plt.xlabel('Month')
plt.ylabel('Total Impressions')
plt.title('Total Impressions per Month')
plt.show()
# Out:
# total impressions: Month
# Apr    1545702.2
# Aug    1164935.7
# Jul    1168917.8
# Jun    1125724.9
# Mar    1597872.4
# May    1608036.8
# Nov    2117531.0
# Oct    2203982.0
# Sep    2112746.0
# Name: Impressions, dtype: float64

# %%
# Create a pivot table to aggregate impressions by city and device
impression_pivot = df.pivot_table(index='City', columns='Device', values='Impressions', aggfunc='sum')

# Plot the stacked bar chart
impression_pivot.plot(kind='barh', stacked=False)
plt.xlabel('City')
plt.ylabel('Impressions')
plt.title('Impressions by City and Device')
plt.show()

# %%
impression_channel= df['Impressions'].groupby(df["Channel"]).sum()
print("impression from channel:",impression_channel)
plt.pie(impression_channel,labels=impression_channel.index,autopct='%1.1f%%',startangle=90)
plt.title('Impression from Channel')
plt.legend(prop={'size': 8})
plt.show()
#
# Out:
# impression from channel: Channel
# Facebook     5439590.6
# Instagram    4840638.1
# Pinterest    4365220.1
# Name: Impressions, dtype: float64

# %%
#impression distribution
plt.figure(figsize=(10, 6))
sns.boxplot(x='Channel', y='Impressions', hue='Device', data=df)
plt.xlabel('Channel')
plt.ylabel('Impressions')
_ = plt.title('Impressions Distribution by Channel and Device')

# %%
like_pivot = df.pivot_table(index='Channel', columns='Device', values='Likes (Reactions)', aggfunc='sum')
print(pivot_table)
# Plot the stacked bar chart
like_pivot.plot(kind='bar', stacked=False)
plt.xlabel('Channel')
plt.ylabel('Likes')
plt.title('Likes by Channel and Device')
plt.show()
#

Comment_Pivot = df.pivot_table(index='Channel', columns='Device', values='Comments', aggfunc='sum')
print(Comment_Pivot)
# Plot the stacked bar chart
Comment_Pivot.plot(kind='bar', stacked=False)
plt.xlabel('Channel')
plt.ylabel('Comments')
plt.title('Comments by Channel and Device')
plt.show()
#
# Out:
# Device     Desktop   Mobile
# Channel
# Facebook   1861.59  1582.80
# Instagram  1780.32  1515.44
# Pinterest  1191.89  1018.59
# Device     Desktop  Mobile
# Channel
# Facebook     15845   10103
# Instagram    18304   11795
# Pinterest    10006    6686

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='City', y='Impressions', hue='Device', data=df)
plt.xlabel('City')
plt.ylabel('Impressions')
_ = plt.title('Impressions Distribution by City and Device')

# %%
impression_clicks=df['Impressions'].groupby(df["Clicks"]).sum()
print("impression from clicks:",impression_clicks)
plt.scatter(df['Impressions'],df['Clicks'])
plt.xlabel('Impressions')
plt.ylabel('Clicks')
plt.title('Impressions vs Clicks')
plt.show()
#
# Out:
# impression from clicks: Clicks
# 0       5531.3
# 1      25305.0
# 2      43571.2
# 3      84011.9
# 4     118708.2
#         ...
# 58      5842.0
# 59      3472.0
# 60      7834.0
# 61      3602.0
# 62      3434.0
# Name: Impressions, Length: 63, dtype: float64

# %%
impression_click_campaign=df['Impressions'].groupby(df["Campaign"]).sum()
print("impression from campaign:",impression_click_campaign)

sns.scatterplot(x='Impressions', y='Clicks', hue='Campaign', data=df)
plt.xlabel('Impressions')
plt.ylabel('Clicks')
plt.title('Impressions vs Clicks by Campaign')
plt.show()
# Out:
# impression from campaign: Campaign
# Fall        2454085.0
# Spring     10851191.6
# Summer      1340172.2
# Name: Impressions, dtype: float64

# %%
corr_matrix=df[["Likes (Reactions)", "Shares", "Comments"]].corr()
print(corr_matrix)
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm')
plt.show()
#
# Out:
#                    Likes (Reactions)    Shares  Comments
# Likes (Reactions)           1.000000  0.298694  0.061299
# Shares                      0.298694  1.000000 -0.008415
# Comments                    0.061299 -0.008415  1.000000
